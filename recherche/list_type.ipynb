# %%
import pandas as  pd
import numpy as  np

# %%
df = pd.read_csv('../data/Anime_data.csv')

# %%
df = df["Producer"]

# %%
df = df.dropna()

# %%
df
# Out:
# 0                                        ['Bandai Visual']
# 1                             ['Sunrise', 'Bandai Visual']
# 2                                 ['Victor Entertainment']
# 3                                        ['Bandai Visual']
# 5        ['TV Tokyo', 'Nihon Ad Systems', 'TV Tokyo Mus...
#                                ...
# 14980                                              ['NHK']
# 14981                                              ['NHK']
# 14988                                        ['Asmik Ace']
# 15001                                             ['AT-X']
# 15013                            ['Universal Music Japan']
# Name: Producer, Length: 7635, dtype: object

# %%
list_type = df.unique()

# %%
list(list_type)
# Out:
# ["['Bandai Visual']",
#  "['Sunrise', 'Bandai Visual']",
#  "['Victor Entertainment']",
#  "['TV Tokyo', 'Nihon Ad Systems', 'TV Tokyo Music', 'Shueisha']",
#  "['Genco', 'Fuji TV', 'Shueisha']",
#  "['OB Planning', 'Studio Jack']",
#  "['VAP', 'Shogakukan Productions', 'Nippon Television Network']",
#  "['TV Tokyo', 'Aniplex', 'Shueisha']",
#  "['Fuji TV', 'TAP', 'Shueisha']",
#  "['Production I.G', 'Nihon Ad Systems']",
#  "['TV Tokyo', 'Sotsu', 'Marvelous', 'Starchild Records', 'Media Factory', 'DAX Production', 'Studio Jack']",
#  "['GDH', 'Pony Canyon', 'CBC']",
#  "['Group TAC', 'Rondo Robe', 'Fuji TV', 'Pioneer LDC']",
#  "['TV Tokyo', 'Aniplex', 'd-rights', 'Tohokushinsha Film Corporation', 'Atelier Musa']",
#  "['Marvelous', 'TBS']",
#  "['TV Tokyo', 'Kadokawa Shoten', 'Nihon Ad Systems', 'Audio Tanaka']",
#  "['Movic', 'Sega', 'TV Tokyo Music', 'Audio Tanaka']",
#  "['TV Tokyo', 'Toei Animation', 'Kadokawa Shoten', 'Movic', 'Sega', 'TV Tokyo Music', 'Audio Tanaka']",
# ...

# %%
import json


with open("../data/list_type", "w") as fp:
    json.dump(list(list_type), fp)
